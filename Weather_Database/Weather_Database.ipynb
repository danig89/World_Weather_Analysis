# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Import linear regression from the SciPy stats module
from scipy.stats import linregress

# %%
# Create new list of 2000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_apy_keys

# %%
# Perform Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_apy_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bdaf3e8151a19ca98ef77e9d31475625

# %%
# Creating an empty list to hold the weather data. 
city_data = []
# Start of run
print("Beginning Data Retrieval")
print("------------------------")

# Create counters.
record_count = 1
set_count = 1

#Looping through each cities list.
for i, city in enumerate(cities):
    
    # Grouping cities by 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create an endpoint URL for a city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1

# Run an API Request for each of the cities. 
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        weather_des = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        
        # Convert Date to ISO 
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": weather_des})
        
# If an error is experienced, skip the city. 
    except Exception as ex:
        print(ex)
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("------------------------")
print("Data Retrieval Complete ")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 1 | peniche
# Processing Record 5 of Set 1 | marsh harbour
# Processing Record 6 of Set 1 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | alofi
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | heinola
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | arica
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | cabo san lucas
# Processing Record 17 of Set 1 | codrington
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | axim
# Processing Record 25 of Set 1 | hambantota
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | balkanabat
# Processing Record 29 of Set 1 | sao joao da barra
# Processing Record 30 of Set 1 | visnes
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | skiros
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 1 | jiddah
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 1 | canoinhas
# Processing Record 37 of Set 1 | chitral
# Processing Record 38 of Set 1 | pahalgam
# Processing Record 39 of Set 1 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 1 | boali
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | datong
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 1 | atambua
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | mentok
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 2 | galgani
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 2 | saint-augustin
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | porto novo
# Processing Record 5 of Set 2 | chara
# Processing Record 6 of Set 2 | cradock
# Processing Record 7 of Set 2 | aykhal
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | mertoyudan
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | fort morgan
# Processing Record 13 of Set 2 | port hardy
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 2 | cangzhou
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | mrirt
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 2 | sokolo
# Processing Record 20 of Set 2 | fengcheng
# Processing Record 21 of Set 2 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 2 | praia da vitoria
# Processing Record 27 of Set 2 | saint-joseph
# Processing Record 28 of Set 2 | huntington
# Processing Record 29 of Set 2 | sitka
# Processing Record 30 of Set 2 | valparaiso
# Processing Record 31 of Set 2 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | joshimath
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | mayor pablo lagerenza
# Processing Record 36 of Set 2 | gobabis
# Processing Record 37 of Set 2 | maple creek
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 2 | caravelas
# Processing Record 41 of Set 2 | pathein
# Processing Record 42 of Set 2 | makokou
# Processing Record 43 of Set 2 | taoudenni
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | sherman
# Processing Record 46 of Set 2 | baykit
# Processing Record 47 of Set 2 | santa cruz
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 2 | lamu
# Processing Record 1 of Set 3 | damghan
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | yulara
# Processing Record 4 of Set 3 | namibe
# Processing Record 5 of Set 3 | buraydah
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | sakaraha
# Processing Record 10 of Set 3 | hobyo
# Processing Record 11 of Set 3 | rockingham
# Processing Record 12 of Set 3 | puerto baquerizo moreno
# Processing Record 13 of Set 3 | rincon
# Processing Record 14 of Set 3 | makat
# Processing Record 15 of Set 3 | visby
# Processing Record 16 of Set 3 | tikhvin
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | grand gaube
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | suhbaatar
# Processing Record 23 of Set 3 | aasiaat
# Processing Record 24 of Set 3 | hamilton
# Processing Record 25 of Set 3 | vostok
# Processing Record 26 of Set 3 | poletayevo
# Processing Record 27 of Set 3 | waipawa
# Processing Record 28 of Set 3 | rio branco
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | marsa matruh
# Processing Record 31 of Set 3 | ambanja
# Processing Record 32 of Set 3 | cape town
# Processing Record 33 of Set 3 | lodja
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | upata
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | ramsgate
# Processing Record 38 of Set 3 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 3 | taseyevo
# Processing Record 40 of Set 3 | belaya gora
# Processing Record 41 of Set 3 | ilulissat
# Processing Record 42 of Set 3 | galveston
# Processing Record 43 of Set 3 | bowen
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | parkhill
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | mahanoro
# Processing Record 48 of Set 3 | skalistyy
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 3 | ilebo
# Processing Record 50 of Set 3 | shimoda
# Processing Record 1 of Set 4 | itarema
# Processing Record 2 of Set 4 | vila franca do campo
# Processing Record 3 of Set 4 | papara
# Processing Record 4 of Set 4 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 4 | sainte-claire
# Processing Record 8 of Set 4 | inta
# Processing Record 9 of Set 4 | riyadh
# Processing Record 10 of Set 4 | hudiksvall
# Processing Record 11 of Set 4 | price
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | roswell
# Processing Record 14 of Set 4 | mizdah
# Processing Record 15 of Set 4 | khatanga
# Processing Record 16 of Set 4 | klaksvik
# Processing Record 17 of Set 4 | bandiagara
# Processing Record 18 of Set 4 | moose factory
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | avera
# Processing Record 21 of Set 4 | abu kamal
# Processing Record 22 of Set 4 | jinsha
# Processing Record 23 of Set 4 | humberto de campos
# Processing Record 24 of Set 4 | kita
# Processing Record 25 of Set 4 | marzuq
# Processing Record 26 of Set 4 | naze
# Processing Record 27 of Set 4 | taltal
# Processing Record 28 of Set 4 | lata
# Processing Record 29 of Set 4 | norman wells
# Processing Record 30 of Set 4 | mach
# Processing Record 31 of Set 4 | zhigansk
# Processing Record 32 of Set 4 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 4 | peking
# Processing Record 34 of Set 4 | bernal
# Processing Record 35 of Set 4 | dinkelsbuhl
# Processing Record 36 of Set 4 | tete
# Processing Record 37 of Set 4 | nanortalik
# Processing Record 38 of Set 4 | vao
# Processing Record 39 of Set 4 | bella vista
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | matara
# Processing Record 42 of Set 4 | tulun
# Processing Record 43 of Set 4 | warqla
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 4 | quebo
# Processing Record 45 of Set 4 | aquiraz
# Processing Record 46 of Set 4 | bobo dioulasso
# Processing Record 47 of Set 4 | maniitsoq
# Processing Record 48 of Set 4 | jamestown
# Processing Record 49 of Set 4 | saint-pierre
# Processing Record 50 of Set 4 | verkhnetulomskiy
# Processing Record 1 of Set 5 | vila velha
# Processing Record 2 of Set 5 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 5 | adrar
# Processing Record 4 of Set 5 | straumen
# Processing Record 5 of Set 5 | bathsheba
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | nantucket
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | bay roberts
# Processing Record 11 of Set 5 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 5 | mudanjiang
# Processing Record 13 of Set 5 | airai
# Processing Record 14 of Set 5 | yar-sale
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | flinders
# Processing Record 17 of Set 5 | provideniya
# Processing Record 18 of Set 5 | upernavik
# Processing Record 19 of Set 5 | barrow
# Processing Record 20 of Set 5 | amapa
# Processing Record 21 of Set 5 | saint-leu
# Processing Record 22 of Set 5 | hadejia
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | patitirion
# Processing Record 25 of Set 5 | ternate
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | san quintin
# Processing Record 28 of Set 5 | gombong
# Processing Record 29 of Set 5 | vestmanna
# Processing Record 30 of Set 5 | sasso marconi
# Processing Record 31 of Set 5 | luang prabang
# Processing Record 32 of Set 5 | svetlaya
# Processing Record 33 of Set 5 | bristol
# Processing Record 34 of Set 5 | meyungs
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 5 | nova soure
# Processing Record 36 of Set 5 | shahapur
# Processing Record 37 of Set 5 | guadalajara
# Processing Record 38 of Set 5 | gamba
# Processing Record 39 of Set 5 | bethel
# Processing Record 40 of Set 5 | nalut
# Processing Record 41 of Set 5 | aklavik
# Processing Record 42 of Set 5 | henties bay
# Processing Record 43 of Set 5 | cayenne
# Processing Record 44 of Set 5 | ingham
# Processing Record 45 of Set 5 | miraflores
# Processing Record 46 of Set 5 | mbuji-mayi
# Processing Record 47 of Set 5 | nueva gorgona
# Processing Record 48 of Set 5 | zachagansk
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 6 | eureka
# Processing Record 2 of Set 6 | salalah
# Processing Record 3 of Set 6 | port hedland
# Processing Record 4 of Set 6 | cartaya
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 6 | zhuanghe
# Processing Record 8 of Set 6 | foam lake
# Processing Record 9 of Set 6 | dali
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | puquio
# Processing Record 12 of Set 6 | waingapu
# Processing Record 13 of Set 6 | trinidad
# Processing Record 14 of Set 6 | tambopata
# Processing Record 15 of Set 6 | vila
# Processing Record 16 of Set 6 | vardo
# Processing Record 17 of Set 6 | quelimane
# Processing Record 18 of Set 6 | chilca
# Processing Record 19 of Set 6 | vanavara
# Processing Record 20 of Set 6 | kismayo
# Processing Record 21 of Set 6 | san jose de rio tinto
# Processing Record 22 of Set 6 | hengshan
# Processing Record 23 of Set 6 | abnub
# Processing Record 24 of Set 6 | port-cartier
# Processing Record 25 of Set 6 | saint george
# Processing Record 26 of Set 6 | beloha
# Processing Record 27 of Set 6 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 6 | sola
# Processing Record 29 of Set 6 | sakakah
# Processing Record 30 of Set 6 | blackwater
# Processing Record 31 of Set 6 | katangli
# Processing Record 32 of Set 6 | touros
# Processing Record 33 of Set 6 | kununurra
# Processing Record 34 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 6 | voi
# Processing Record 36 of Set 6 | taburi
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 6 | rocha
# Processing Record 38 of Set 6 | tankara
# Processing Record 39 of Set 6 | asau
# Processing Record 40 of Set 6 | cherskiy
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | pacific grove
# Processing Record 44 of Set 6 | vangaindrano
# Processing Record 45 of Set 6 | albert lea
# Processing Record 46 of Set 6 | vuktyl
# Processing Record 47 of Set 6 | huadian
# Processing Record 48 of Set 6 | laguna
# Processing Record 49 of Set 6 | aksarka
# Processing Record 50 of Set 6 | kristinehamn
# Processing Record 1 of Set 7 | bumba
# Processing Record 2 of Set 7 | sao felix do xingu
# Processing Record 3 of Set 7 | kruisfontein
# Processing Record 4 of Set 7 | satitoa
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 7 | kathu
# Processing Record 6 of Set 7 | beira
# Processing Record 7 of Set 7 | kupang
# Processing Record 8 of Set 7 | derzhavinsk
# Processing Record 9 of Set 7 | tezu
# Processing Record 10 of Set 7 | paraiso
# Processing Record 11 of Set 7 | lazaro cardenas
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | riviere-au-renard
# Processing Record 14 of Set 7 | lima
# Processing Record 15 of Set 7 | wewak
# Processing Record 16 of Set 7 | skovde
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 7 | soke
# Processing Record 18 of Set 7 | kalmunai
# Processing Record 19 of Set 7 | port blair
# Processing Record 20 of Set 7 | mnogovershinnyy
# Processing Record 21 of Set 7 | polewali
# Processing Record 22 of Set 7 | bud
# Processing Record 23 of Set 7 | sioux lookout
# Processing Record 24 of Set 7 | maralal
# Processing Record 25 of Set 7 | sungaipenuh
# Processing Record 26 of Set 7 | takaka
# Processing Record 27 of Set 7 | cedar city
# Processing Record 28 of Set 7 | vitim
# Processing Record 29 of Set 7 | sylva
# Processing Record 30 of Set 7 | mahon
# Processing Record 31 of Set 7 | lucapa
# Processing Record 32 of Set 7 | shimanovsk
# Processing Record 33 of Set 7 | magadan
# Processing Record 34 of Set 7 | bokspits
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 7 | tiksi
# Processing Record 36 of Set 7 | plainview
# Processing Record 37 of Set 7 | torbay
# Processing Record 38 of Set 7 | ambon
# Processing Record 39 of Set 7 | aberystwyth
# Processing Record 40 of Set 7 | mackay
# Processing Record 41 of Set 7 | labutta
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 7 | karratha
# Processing Record 43 of Set 7 | longyearbyen
# Processing Record 44 of Set 7 | iqaluit
# Processing Record 45 of Set 7 | kawalu
# Processing Record 46 of Set 7 | barcelona
# Processing Record 47 of Set 7 | isangel
# Processing Record 48 of Set 7 | najran
# Processing Record 49 of Set 7 | fiumicino
# Processing Record 50 of Set 7 | maxixe
# Processing Record 1 of Set 8 | chapais
# Processing Record 2 of Set 8 | imeni morozova
# Processing Record 3 of Set 8 | vokhma
# Processing Record 4 of Set 8 | tiznit
# Processing Record 5 of Set 8 | wapakoneta
# Processing Record 6 of Set 8 | temple
# Processing Record 7 of Set 8 | new norfolk
# Processing Record 8 of Set 8 | miri
# Processing Record 9 of Set 8 | madang
# Processing Record 10 of Set 8 | kaniama
# Processing Record 11 of Set 8 | kavieng
# Processing Record 12 of Set 8 | damaturu
# Processing Record 13 of Set 8 | warrnambool
# Processing Record 14 of Set 8 | dhampur
# Processing Record 15 of Set 8 | bambous virieux
# Processing Record 16 of Set 8 | kurmanayevka
# Processing Record 17 of Set 8 | progreso
# Processing Record 18 of Set 8 | westpunt
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 8 | kedrovka
# Processing Record 20 of Set 8 | beringovskiy
# Processing Record 21 of Set 8 | roebourne
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | raudeberg
# Processing Record 24 of Set 8 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 8 | kadyy
# Processing Record 26 of Set 8 | athabasca
# Processing Record 27 of Set 8 | dukat
# Processing Record 28 of Set 8 | bistrica
# Processing Record 29 of Set 8 | san francisco del mar
# Processing Record 30 of Set 8 | tikheron
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 8 | ostrovnoy
# Processing Record 32 of Set 8 | wanning
# Processing Record 33 of Set 8 | zeya
# Processing Record 34 of Set 8 | lavrentiya
# Processing Record 35 of Set 8 | colon
# Processing Record 36 of Set 8 | sorland
# Processing Record 37 of Set 8 | tual
# Processing Record 38 of Set 8 | yunjinghong
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 8 | yeppoon
# Processing Record 40 of Set 8 | abha
# Processing Record 41 of Set 8 | sobolevo
# Processing Record 42 of Set 8 | nome
# Processing Record 43 of Set 8 | adre
# Processing Record 44 of Set 8 | zdolbuniv
# Processing Record 45 of Set 8 | maputo
# Processing Record 46 of Set 8 | inirida
# Processing Record 47 of Set 8 | lorengau
# Processing Record 48 of Set 8 | broken hill
# Processing Record 49 of Set 8 | cabedelo
# Processing Record 50 of Set 8 | bendigo
# Processing Record 1 of Set 9 | sao francisco de assis
# Processing Record 2 of Set 9 | santa maria del oro
# Processing Record 3 of Set 9 | mackenzie
# Processing Record 4 of Set 9 | port keats
# Processing Record 5 of Set 9 | kudahuvadhoo
# Processing Record 6 of Set 9 | venice
# Processing Record 7 of Set 9 | shibarghan
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 9 | hay river
# Processing Record 9 of Set 9 | qeshm
# Processing Record 10 of Set 9 | samarai
# Processing Record 11 of Set 9 | okhotsk
# Processing Record 12 of Set 9 | inderborskiy
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 9 | yuzhno-sukhokumsk
# Processing Record 14 of Set 9 | dickinson
# Processing Record 15 of Set 9 | faanui
# Processing Record 16 of Set 9 | panaba
# Processing Record 17 of Set 9 | clyde river
# Processing Record 18 of Set 9 | ngukurr
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 9 | barra do bugres
# Processing Record 20 of Set 9 | richards bay
# Processing Record 21 of Set 9 | vilhena
# Processing Record 22 of Set 9 | la libertad
# Processing Record 23 of Set 9 | talcahuano
# Processing Record 24 of Set 9 | dakar
# Processing Record 25 of Set 9 | craig
# Processing Record 26 of Set 9 | takoradi
# Processing Record 27 of Set 9 | ahipara
# Processing Record 28 of Set 9 | sechura
# Processing Record 29 of Set 9 | byron bay
# Processing Record 30 of Set 9 | tevaitoa
# Processing Record 31 of Set 9 | domazlice
# Processing Record 32 of Set 9 | bilma
# Processing Record 33 of Set 9 | shingu
# Processing Record 34 of Set 9 | le port
# Processing Record 35 of Set 9 | jurado
# Processing Record 36 of Set 9 | parakou
# Processing Record 37 of Set 9 | nemuro
# Processing Record 38 of Set 9 | gat
# Processing Record 39 of Set 9 | gondanglegi
# Processing Record 40 of Set 9 | eyl
# Processing Record 41 of Set 9 | cap malheureux
# Processing Record 42 of Set 9 | goderich
# Processing Record 43 of Set 9 | butterworth
# Processing Record 44 of Set 9 | evensk
# Processing Record 45 of Set 9 | faya
# Processing Record 46 of Set 9 | nirasaki
# Processing Record 47 of Set 9 | sanming
# Processing Record 48 of Set 9 | dudinka
# Processing Record 49 of Set 9 | san ramon
# Processing Record 50 of Set 9 | florianopolis
# Processing Record 1 of Set 10 | mattru
# Processing Record 2 of Set 10 | tsuyama
# Processing Record 3 of Set 10 | kavali
# Processing Record 4 of Set 10 | fredericton
# Processing Record 5 of Set 10 | galle
# Processing Record 6 of Set 10 | wattegama
# Processing Record 7 of Set 10 | camacha
# Processing Record 8 of Set 10 | ewa beach
# Processing Record 9 of Set 10 | noumea
# Processing Record 10 of Set 10 | vite
# Processing Record 11 of Set 10 | suicheng
# Processing Record 12 of Set 10 | severobaykalsk
# Processing Record 13 of Set 10 | dzhusaly
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 10 | zarya
# Processing Record 15 of Set 10 | inuvik
# Processing Record 16 of Set 10 | teguldet
# Processing Record 17 of Set 10 | breytovo
# Processing Record 18 of Set 10 | qaqortoq
# Processing Record 19 of Set 10 | lakes entrance
# Processing Record 20 of Set 10 | brindisi
# Processing Record 21 of Set 10 | comodoro rivadavia
# Processing Record 22 of Set 10 | babanusah
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 10 | pemba
# Processing Record 24 of Set 10 | saryshagan
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 10 | myhove
# Processing Record 26 of Set 10 | cairns
# Processing Record 27 of Set 10 | burnie
# Processing Record 28 of Set 10 | ponnani
# Processing Record 29 of Set 10 | ahumada
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 10 | huron
# Processing Record 31 of Set 10 | scarborough
# Processing Record 32 of Set 10 | tessalit
# Processing Record 33 of Set 10 | honiara
# Processing Record 34 of Set 10 | olafsvik
# Processing Record 35 of Set 10 | angoche
# Processing Record 36 of Set 10 | kijang
# Processing Record 37 of Set 10 | luena
# Processing Record 38 of Set 10 | linxia
# Processing Record 39 of Set 10 | port moresby
# Processing Record 40 of Set 10 | grindavik
# Processing Record 41 of Set 10 | takab
# Processing Record 42 of Set 10 | roma
# Processing Record 43 of Set 10 | candawaga
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 10 | salta
# Processing Record 45 of Set 10 | kuche
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 10 | portland
# Processing Record 47 of Set 10 | puerto del rosario
# Processing Record 48 of Set 10 | kangaatsiaq
# Processing Record 49 of Set 10 | ketchikan
# Processing Record 50 of Set 10 | maragogi
# Processing Record 1 of Set 11 | sanguem
# Processing Record 2 of Set 11 | diffa
# Processing Record 3 of Set 11 | polunochnoye
# Processing Record 4 of Set 11 | bandarbeyla
# Processing Record 5 of Set 11 | tecolutla
# Processing Record 6 of Set 11 | jiazi
# Processing Record 7 of Set 11 | cadillac
# Processing Record 8 of Set 11 | tilichiki
# Processing Record 9 of Set 11 | muscat
# Processing Record 10 of Set 11 | kandrian
# Processing Record 11 of Set 11 | yangambi
# Processing Record 12 of Set 11 | husavik
# Processing Record 13 of Set 11 | valdivia
# Processing Record 14 of Set 11 | ossora
# Processing Record 15 of Set 11 | loa janan
# Processing Record 16 of Set 11 | kishanganj
# Processing Record 17 of Set 11 | ponta do sol
# Processing Record 18 of Set 11 | conway
# Processing Record 19 of Set 11 | abu dhabi
# Processing Record 20 of Set 11 | hervey bay
# Processing Record 21 of Set 11 | nuuk
# Processing Record 22 of Set 11 | sambava
# Processing Record 23 of Set 11 | paita
# Processing Record 24 of Set 11 | itoman
# Processing Record 25 of Set 11 | hami
# Processing Record 26 of Set 11 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 11 | cullman
# Processing Record 28 of Set 11 | korla
# Processing Record 29 of Set 11 | marienburg
# Processing Record 30 of Set 11 | jinzhou
# Processing Record 31 of Set 11 | makakilo city
# Processing Record 32 of Set 11 | chicama
# Processing Record 33 of Set 11 | hadgaon
# Processing Record 34 of Set 11 | bethlehem
# Processing Record 35 of Set 11 | voh
# Processing Record 36 of Set 11 | sept-iles
# Processing Record 37 of Set 11 | den chai
# Processing Record 38 of Set 11 | iranshahr
# Processing Record 39 of Set 11 | melville
# Processing Record 40 of Set 11 | doctor pedro p. pena
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 11 | miguel hidalgo
# Processing Record 42 of Set 11 | zhicheng
# Processing Record 43 of Set 11 | murgab
# Processing Record 44 of Set 11 | grand-lahou
# Processing Record 45 of Set 11 | rayong
# Processing Record 46 of Set 11 | tidore
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 11 | robertsport
# Processing Record 48 of Set 11 | opuwo
# Processing Record 49 of Set 11 | tubruq
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 11 | rabo de peixe
# Processing Record 1 of Set 12 | souillac
# Processing Record 2 of Set 12 | mount gambier
# Processing Record 3 of Set 12 | strezhevoy
# Processing Record 4 of Set 12 | kidal
# Processing Record 5 of Set 12 | hearst
# Processing Record 6 of Set 12 | oriximina
# Processing Record 7 of Set 12 | deputatskiy
# Processing Record 8 of Set 12 | mandalgovi
# Processing Record 9 of Set 12 | north bend
# Processing Record 10 of Set 12 | komsomolskiy
# Processing Record 11 of Set 12 | san patricio
# Processing Record 12 of Set 12 | filadelfia
# Processing Record 13 of Set 12 | san andres
# Processing Record 14 of Set 12 | orzu
# Processing Record 15 of Set 12 | mishan
# Processing Record 16 of Set 12 | bachaquero
# Processing Record 17 of Set 12 | kottagudem
# Processing Record 18 of Set 12 | sorong
# Processing Record 19 of Set 12 | barela
# Processing Record 20 of Set 12 | krasnoselkup
# Processing Record 21 of Set 12 | kargasok
# Processing Record 22 of Set 12 | la ceiba
# Processing Record 23 of Set 12 | kaoma
# Processing Record 24 of Set 12 | saint anthony
# Processing Record 25 of Set 12 | barbar
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 12 | puerto escondido
# Processing Record 27 of Set 12 | hofn
# Processing Record 28 of Set 12 | luganville
# Processing Record 29 of Set 12 | darhan
# Processing Record 30 of Set 12 | dalvik
# Processing Record 31 of Set 12 | umm durman
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 12 | imola
# Processing Record 33 of Set 12 | aitape
# Processing Record 34 of Set 12 | boone
# Processing Record 35 of Set 12 | olinda
# Processing Record 36 of Set 12 | malakal
# Processing Record 37 of Set 12 | las palmas
# Processing Record 38 of Set 12 | loiza
# Processing Record 39 of Set 12 | ndele
# Processing Record 40 of Set 12 | luanda
# Processing Record 41 of Set 12 | kutum
# Processing Record 42 of Set 12 | hirara
# Processing Record 43 of Set 12 | leningradskiy
# Processing Record 44 of Set 12 | lufilufi
# Processing Record 45 of Set 12 | bustonkala
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 12 | shar
# Processing Record 47 of Set 12 | petukhovo
# Processing Record 48 of Set 12 | los llanos de aridane
# Processing Record 49 of Set 12 | lagoa
# Processing Record 50 of Set 12 | japura
# Processing Record 1 of Set 13 | college
# Processing Record 2 of Set 13 | el alto
# Processing Record 3 of Set 13 | gravdal
# Processing Record 4 of Set 13 | nichinan
# Processing Record 5 of Set 13 | salto
# Processing Record 6 of Set 13 | mayaposi
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 13 | alamos
# Processing Record 8 of Set 13 | blagoyevo
# Processing Record 9 of Set 13 | mbeya
# Processing Record 10 of Set 13 | yumen
# Processing Record 11 of Set 13 | alexandria
# Processing Record 12 of Set 13 | tuatapere
# Processing Record 13 of Set 13 | hun
# Processing Record 14 of Set 13 | synya
# Processing Record 15 of Set 13 | honningsvag
# Processing Record 16 of Set 13 | marsala
# Processing Record 17 of Set 13 | sosnovka
# Processing Record 18 of Set 13 | nhulunbuy
# Processing Record 19 of Set 13 | prachuap khiri khan
# Processing Record 20 of Set 13 | soria
# Processing Record 21 of Set 13 | maldonado
# Processing Record 22 of Set 13 | opelousas
# Processing Record 23 of Set 13 | sayat
# Processing Record 24 of Set 13 | quatre cocos
# Processing Record 25 of Set 13 | kantunilkin
# Processing Record 26 of Set 13 | manavalakurichi
# Processing Record 27 of Set 13 | carutapera
# Processing Record 28 of Set 13 | kiruna
# Processing Record 29 of Set 13 | acajutla
# Processing Record 30 of Set 13 | mitu
# Processing Record 31 of Set 13 | half moon bay
# Processing Record 32 of Set 13 | echt
# Processing Record 33 of Set 13 | katherine
# Processing Record 34 of Set 13 | novokayakent
# Processing Record 35 of Set 13 | mmabatho
# Processing Record 36 of Set 13 | havoysund
# Processing Record 37 of Set 13 | podgorenskiy
# Processing Record 38 of Set 13 | shirokiy
# Processing Record 39 of Set 13 | kytlym
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 13 | zatoka
# Processing Record 41 of Set 13 | markova
# Processing Record 42 of Set 13 | malavalli
# Processing Record 43 of Set 13 | santa rosa del sur
# Processing Record 44 of Set 13 | sciacca
# Processing Record 45 of Set 13 | rawson
# Processing Record 46 of Set 13 | buritis
# Processing Record 47 of Set 13 | chumikan
# Processing Record 48 of Set 13 | palu
# Processing Record 49 of Set 13 | turukhansk
# Processing Record 50 of Set 13 | koroni
# Processing Record 1 of Set 14 | alappuzha
# Processing Record 2 of Set 14 | flores
# Processing Record 3 of Set 14 | tandil
# Processing Record 4 of Set 14 | salinopolis
# Processing Record 5 of Set 14 | mendahara
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 14 | muhos
# Processing Record 7 of Set 14 | wonji
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 14 | rudbar
# Processing Record 9 of Set 14 | gerash
# Processing Record 10 of Set 14 | argayash
# Processing Record 11 of Set 14 | lunglei
# Processing Record 12 of Set 14 | hendijan
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 14 | kuryk
# Processing Record 14 of Set 14 | broome
# Processing Record 15 of Set 14 | aripuana
# Processing Record 16 of Set 14 | alice springs
# Processing Record 17 of Set 14 | bukan
# Processing Record 18 of Set 14 | shangzhi
# Processing Record 19 of Set 14 | revelganj
# Processing Record 20 of Set 14 | mogadishu
# Processing Record 21 of Set 14 | canavieiras
# Processing Record 22 of Set 14 | beyneu
# Processing Record 23 of Set 14 | sundumbili
# Processing Record 24 of Set 14 | san felipe
# Processing Record 25 of Set 14 | sayyan
# Processing Record 26 of Set 14 | parola
# Processing Record 27 of Set 14 | temaraia
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 14 | dovolnoye
# Processing Record 29 of Set 14 | cabinda
# Processing Record 30 of Set 14 | xiaoweizhai
# Processing Record 31 of Set 14 | bosaso
# Processing Record 32 of Set 14 | san rafael del sur
# Processing Record 33 of Set 14 | matagami
# Processing Record 34 of Set 14 | luan
# Processing Record 35 of Set 14 | sembe
# Processing Record 36 of Set 14 | kahului
# Processing Record 37 of Set 14 | qandala
# Processing Record 38 of Set 14 | zhenlai
# Processing Record 39 of Set 14 | fairview
# Processing Record 40 of Set 14 | shache
# Processing Record 41 of Set 14 | omboue
# Processing Record 42 of Set 14 | bayan
# Processing Record 43 of Set 14 | saint simons
# Processing Record 44 of Set 14 | harper
# Processing Record 45 of Set 14 | fare
# Processing Record 46 of Set 14 | miami
# Processing Record 47 of Set 14 | oussouye
# Processing Record 48 of Set 14 | san isidro
# Processing Record 49 of Set 14 | araouane
# Processing Record 50 of Set 14 | kieta
# Processing Record 1 of Set 15 | kirakira
# Processing Record 2 of Set 15 | pitimbu
# Processing Record 3 of Set 15 | matay
# Processing Record 4 of Set 15 | amatitan
# Processing Record 5 of Set 15 | almeirim
# Processing Record 6 of Set 15 | leshukonskoye
# Processing Record 7 of Set 15 | buchanan
# Processing Record 8 of Set 15 | mandan
# Processing Record 9 of Set 15 | sturlic
# Processing Record 10 of Set 15 | altus
# Processing Record 11 of Set 15 | sorsk
# Processing Record 12 of Set 15 | svetlogorsk
# Processing Record 13 of Set 15 | la roda
# Processing Record 14 of Set 15 | ostersund
# Processing Record 15 of Set 15 | jatai
# Processing Record 16 of Set 15 | tucuma
# Processing Record 17 of Set 15 | mtambile
# Processing Record 18 of Set 15 | urumqi
# Processing Record 19 of Set 15 | necochea
# Processing Record 20 of Set 15 | arraias
# Processing Record 21 of Set 15 | alvaraes
# Processing Record 22 of Set 15 | iturama
# Processing Record 23 of Set 15 | kofele
# Processing Record 24 of Set 15 | bubaque
# Processing Record 25 of Set 15 | auki
# Processing Record 26 of Set 15 | kavaratti
# Processing Record 27 of Set 15 | santa maria
# Processing Record 28 of Set 15 | dogbo
# Processing Record 29 of Set 15 | coquimbo
# Processing Record 30 of Set 15 | wentzville
# Processing Record 31 of Set 15 | liniere
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 15 | hurghada
# Processing Record 33 of Set 15 | mugur-aksy
# Processing Record 34 of Set 15 | am timan
# Processing Record 35 of Set 15 | elat
# Processing Record 36 of Set 15 | onega
# Processing Record 37 of Set 15 | ust-kut
# Processing Record 38 of Set 15 | severo-yeniseyskiy
# Processing Record 39 of Set 15 | champerico
# Processing Record 40 of Set 15 | plettenberg bay
# Processing Record 41 of Set 15 | louisbourg
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 15 | bobrovskiy
# Processing Record 43 of Set 15 | sarankhola
# Processing Record 44 of Set 15 | kerman
# Processing Record 45 of Set 15 | xuanzhou
# Processing Record 46 of Set 15 | sabha
# Processing Record 47 of Set 15 | anadyr
# Processing Record 48 of Set 15 | yarmouth
# Processing Record 49 of Set 15 | alamosa
# Processing Record 50 of Set 15 | san cristobal
# Processing Record 1 of Set 16 | labuhan
# Processing Record 2 of Set 16 | hovd
# Processing Record 3 of Set 16 | vidim
# Processing Record 4 of Set 16 | the pas
# Processing Record 5 of Set 16 | jalalabad
# Processing Record 6 of Set 16 | jalu
# Processing Record 7 of Set 16 | payo
# Processing Record 8 of Set 16 | astaneh-ye ashrafiyeh
# Processing Record 9 of Set 16 | bushehr
# ------------------------
# Data Retrieval Complete
# ------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 50.8385, 'lat': 28.9684},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 60.8,
#   'feels_like': 60.49,
#   'temp_min': 60.8,
#   'temp_max': 60.8,
#   'pressure': 1013,
#   'humidity': 88},
#  'visibility': 8000,
#  'wind': {'speed': 4.61, 'deg': 30},
#  'clouds': {'all': 20},
#  'dt': 1610830801,
#  'sys': {'type': 1,
#   'id': 7444,
#   'country': 'IR',
#   'sunrise': 1610854245,
#   'sunset': 1610892137},
#  'timezone': 12600,
#  'id': 139817,
#  'name': 'Bushehr',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
