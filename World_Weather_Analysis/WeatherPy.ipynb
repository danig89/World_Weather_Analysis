# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 622

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_apy_keys

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_apy_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bdaf3e8151a19ca98ef77e9d31475625

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | roros
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | bilma
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | zelenoborsk
# Processing Record 13 of Set 1 | honiara
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | jilib
# Processing Record 16 of Set 1 | komsomolskiy
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | toguchin
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | nantucket
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | novaya zaimka
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | belaya gora
# Processing Record 37 of Set 1 | bansgaon
# Processing Record 38 of Set 1 | broome
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | kavaratti
# Processing Record 42 of Set 1 | bonfim
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | dasoguz
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | tual
# Processing Record 50 of Set 1 | san luis
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | turka
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 2 | nizhniy kuranakh
# Processing Record 6 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 2 | urucara
# Processing Record 8 of Set 2 | kloulklubed
# Processing Record 9 of Set 2 | adrar
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | salinopolis
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | sumedang
# Processing Record 16 of Set 2 | alcudia
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | tasiilaq
# Processing Record 20 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 2 | faya
# Processing Record 22 of Set 2 | sohag
# Processing Record 23 of Set 2 | epe
# Processing Record 24 of Set 2 | sioux lookout
# Processing Record 25 of Set 2 | alofi
# Processing Record 26 of Set 2 | soto la marina
# Processing Record 27 of Set 2 | rantepao
# Processing Record 28 of Set 2 | chumikan
# Processing Record 29 of Set 2 | opuwo
# Processing Record 30 of Set 2 | hobyo
# Processing Record 31 of Set 2 | lixourion
# Processing Record 32 of Set 2 | boguchany
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | springbok
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 2 | oak park
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | evensk
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | northam
# Processing Record 43 of Set 2 | boende
# Processing Record 44 of Set 2 | berlevag
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | mlowo
# Processing Record 1 of Set 3 | buala
# Processing Record 2 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 3 | fairbanks
# Processing Record 4 of Set 3 | kununurra
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | dingle
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | samokov
# Processing Record 10 of Set 3 | takoradi
# Processing Record 11 of Set 3 | maraa
# Processing Record 12 of Set 3 | neiafu
# Processing Record 13 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 14 of Set 3 | sale
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | shimoda
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | sao joao da barra
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | birjand
# Processing Record 22 of Set 3 | guerrero negro
# Processing Record 23 of Set 3 | elko
# Processing Record 24 of Set 3 | sitka
# Processing Record 25 of Set 3 | gladstone
# Processing Record 26 of Set 3 | ilulissat
# Processing Record 27 of Set 3 | deputatskiy
# Processing Record 28 of Set 3 | necochea
# Processing Record 29 of Set 3 | nanortalik
# Processing Record 30 of Set 3 | souillac
# Processing Record 31 of Set 3 | kaura namoda
# Processing Record 32 of Set 3 | batagay-alyta
# Processing Record 33 of Set 3 | palmeiras de goias
# Processing Record 34 of Set 3 | manado
# Processing Record 35 of Set 3 | muros
# Processing Record 36 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 37 of Set 3 | keetmanshoop
# Processing Record 38 of Set 3 | hirara
# Processing Record 39 of Set 3 | norman wells
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | isangel
# Processing Record 42 of Set 3 | port-gentil
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | bawku
# Processing Record 45 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 3 | ust-ilimsk
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | cherskiy
# Processing Record 49 of Set 3 | manaus
# Processing Record 50 of Set 3 | palmer
# Processing Record 1 of Set 4 | nelson bay
# Processing Record 2 of Set 4 | constitucion
# Processing Record 3 of Set 4 | lujiang
# Processing Record 4 of Set 4 | bluefields
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | dedza
# Processing Record 7 of Set 4 | saint-louis
# Processing Record 8 of Set 4 | jishu
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | falmouth
# Processing Record 11 of Set 4 | atuona
# Processing Record 12 of Set 4 | conway
# Processing Record 13 of Set 4 | puri
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | imeni poliny osipenko
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | namibe
# Processing Record 18 of Set 4 | batagay
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | chernyshevskiy
# Processing Record 22 of Set 4 | trairi
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | tucumcari
# Processing Record 25 of Set 4 | goderich
# Processing Record 26 of Set 4 | newport
# Processing Record 27 of Set 4 | barrow
# Processing Record 28 of Set 4 | lavrentiya
# Processing Record 29 of Set 4 | port blair
# Processing Record 30 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 4 | akdepe
# Processing Record 32 of Set 4 | san quintin
# Processing Record 33 of Set 4 | asfi
# Processing Record 34 of Set 4 | tautira
# Processing Record 35 of Set 4 | grand gaube
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 4 | brindisi
# Processing Record 43 of Set 4 | morant bay
# Processing Record 44 of Set 4 | onega
# Processing Record 45 of Set 4 | selty
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | port macquarie
# Processing Record 48 of Set 4 | buraydah
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 4 | boulder city
# Processing Record 1 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 5 | strezhevoy
# Processing Record 4 of Set 5 | berekum
# Processing Record 5 of Set 5 | nefteyugansk
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | harlingen
# Processing Record 8 of Set 5 | havre-saint-pierre
# Processing Record 9 of Set 5 | tessalit
# Processing Record 10 of Set 5 | port lincoln
# Processing Record 11 of Set 5 | deming
# Processing Record 12 of Set 5 | korla
# Processing Record 13 of Set 5 | qafsah
# City not found. Skipping...
# Processing Record 14 of Set 5 | chicama
# Processing Record 15 of Set 5 | yellowknife
# Processing Record 16 of Set 5 | tiarei
# Processing Record 17 of Set 5 | kasongo-lunda
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | sangar
# Processing Record 20 of Set 5 | port shepstone
# Processing Record 21 of Set 5 | masuguru
# Processing Record 22 of Set 5 | tomatlan
# Processing Record 23 of Set 5 | namatanai
# Processing Record 24 of Set 5 | astoria
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | tarko-sale
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | buchanan
# Processing Record 29 of Set 5 | pfullendorf
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 5 | nha trang
# Processing Record 33 of Set 5 | afua
# Processing Record 34 of Set 5 | saint-joseph
# Processing Record 35 of Set 5 | camacha
# Processing Record 36 of Set 5 | ahipara
# Processing Record 37 of Set 5 | kirensk
# Processing Record 38 of Set 5 | mehamn
# Processing Record 39 of Set 5 | pevek
# Processing Record 40 of Set 5 | college
# Processing Record 41 of Set 5 | aripuana
# Processing Record 42 of Set 5 | new norfolk
# Processing Record 43 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 44 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 5 | santo tomas
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | lander
# Processing Record 48 of Set 5 | zhigansk
# Processing Record 49 of Set 5 | antalaha
# Processing Record 50 of Set 5 | sao filipe
# Processing Record 1 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 2 of Set 6 | reconquista
# Processing Record 3 of Set 6 | half moon bay
# Processing Record 4 of Set 6 | whitianga
# Processing Record 5 of Set 6 | margate
# Processing Record 6 of Set 6 | praia da vitoria
# Processing Record 7 of Set 6 | mount isa
# Processing Record 8 of Set 6 | biggar
# Processing Record 9 of Set 6 | fengkou
# Processing Record 10 of Set 6 | sorong
# Processing Record 11 of Set 6 | yaan
# Processing Record 12 of Set 6 | hay river
# Processing Record 13 of Set 6 | antofagasta
# Processing Record 14 of Set 6 | khovu-aksy
# Processing Record 15 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 6 | muroto
# Processing Record 17 of Set 6 | dvinskoy
# Processing Record 18 of Set 6 | falun
# Processing Record 19 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 20 of Set 6 | genhe
# Processing Record 21 of Set 6 | bethel
# Processing Record 22 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 23 of Set 6 | nemuro
# Processing Record 24 of Set 6 | karratha
# Processing Record 25 of Set 6 | olga
# Processing Record 26 of Set 6 | jumla
# Processing Record 27 of Set 6 | eenhana
# Processing Record 28 of Set 6 | peniche
# Processing Record 29 of Set 6 | bambous virieux
# Processing Record 30 of Set 6 | florianopolis
# Processing Record 31 of Set 6 | anupgarh
# Processing Record 32 of Set 6 | henties bay
# Processing Record 33 of Set 6 | barcelos
# Processing Record 34 of Set 6 | saint-philippe
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | luderitz
# Processing Record 37 of Set 6 | abha
# Processing Record 38 of Set 6 | stepnogorsk
# Processing Record 39 of Set 6 | sfantu gheorghe
# Processing Record 40 of Set 6 | la palma
# Processing Record 41 of Set 6 | hirado
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | tczew
# Processing Record 44 of Set 6 | puerto leguizamo
# Processing Record 45 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 6 | qaqortoq
# Processing Record 47 of Set 6 | state college
# Processing Record 48 of Set 6 | auki
# Processing Record 49 of Set 6 | adre
# Processing Record 50 of Set 6 | viedma
# Processing Record 1 of Set 7 | olinda
# Processing Record 2 of Set 7 | pontefract
# Processing Record 3 of Set 7 | oranjemund
# Processing Record 4 of Set 7 | cayenne
# Processing Record 5 of Set 7 | mareeba
# Processing Record 6 of Set 7 | nyzhnya duvanka
# Processing Record 7 of Set 7 | mahebourg
# Processing Record 8 of Set 7 | ponta do sol
# Processing Record 9 of Set 7 | linxi
# Processing Record 10 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 12 of Set 7 | makakilo city
# Processing Record 13 of Set 7 | tecoanapa
# Processing Record 14 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 7 | mahibadhoo
# Processing Record 16 of Set 7 | koroni
# Processing Record 17 of Set 7 | flinders
# Processing Record 18 of Set 7 | vao
# Processing Record 19 of Set 7 | fredericton
# Processing Record 20 of Set 7 | morondava
# Processing Record 21 of Set 7 | merauke
# Processing Record 22 of Set 7 | boddam
# Processing Record 23 of Set 7 | saldanha
# Processing Record 24 of Set 7 | areka
# Processing Record 25 of Set 7 | gangarampur
# Processing Record 26 of Set 7 | ochakiv
# Processing Record 27 of Set 7 | mujiayingzi
# Processing Record 28 of Set 7 | west bay
# Processing Record 29 of Set 7 | lagoa
# Processing Record 30 of Set 7 | sayyan
# Processing Record 31 of Set 7 | matara
# Processing Record 32 of Set 7 | waipawa
# Processing Record 33 of Set 7 | dalvik
# Processing Record 34 of Set 7 | prince rupert
# Processing Record 35 of Set 7 | aksu
# Processing Record 36 of Set 7 | khorixas
# Processing Record 37 of Set 7 | guiren
# Processing Record 38 of Set 7 | ternate
# Processing Record 39 of Set 7 | bundaberg
# Processing Record 40 of Set 7 | chirawa
# Processing Record 41 of Set 7 | zhezkazgan
# Processing Record 42 of Set 7 | changli
# Processing Record 43 of Set 7 | zhuhai
# Processing Record 44 of Set 7 | lichuan
# Processing Record 45 of Set 7 | alice
# Processing Record 46 of Set 7 | nyaunglebin
# Processing Record 47 of Set 7 | diffa
# Processing Record 48 of Set 7 | kampot
# Processing Record 49 of Set 7 | dembi dolo
# Processing Record 50 of Set 7 | kodinsk
# Processing Record 1 of Set 8 | inta
# Processing Record 2 of Set 8 | zarichne
# Processing Record 3 of Set 8 | price
# Processing Record 4 of Set 8 | shubarkuduk
# Processing Record 5 of Set 8 | tuatapere
# Processing Record 6 of Set 8 | greeneville
# Processing Record 7 of Set 8 | encruzilhada
# Processing Record 8 of Set 8 | ancud
# Processing Record 9 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 8 | avigliana
# Processing Record 11 of Set 8 | langxiang
# Processing Record 12 of Set 8 | ballyshannon
# Processing Record 13 of Set 8 | iquique
# Processing Record 14 of Set 8 | mananjary
# Processing Record 15 of Set 8 | hualmay
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | taseyevo
# Processing Record 18 of Set 8 | havoysund
# Processing Record 19 of Set 8 | hasaki
# Processing Record 20 of Set 8 | maceio
# Processing Record 21 of Set 8 | griffith
# Processing Record 22 of Set 8 | cooma
# Processing Record 23 of Set 8 | senador guiomard
# Processing Record 24 of Set 8 | kleck
# City not found. Skipping...
# Processing Record 25 of Set 8 | otane
# Processing Record 26 of Set 8 | mineiros
# Processing Record 27 of Set 8 | ambon
# Processing Record 28 of Set 8 | belmonte
# Processing Record 29 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 8 | maridi
# Processing Record 31 of Set 8 | aklavik
# Processing Record 32 of Set 8 | avera
# Processing Record 33 of Set 8 | zhigalovo
# Processing Record 34 of Set 8 | luanda
# Processing Record 35 of Set 8 | victoria
# Processing Record 36 of Set 8 | clifton springs
# Processing Record 37 of Set 8 | hokitika
# Processing Record 38 of Set 8 | bosaso
# Processing Record 39 of Set 8 | puteyets
# Processing Record 40 of Set 8 | basco
# Processing Record 41 of Set 8 | atasu
# Processing Record 42 of Set 8 | ulaangom
# Processing Record 43 of Set 8 | barcelona
# Processing Record 44 of Set 8 | oktyabrskiy
# Processing Record 45 of Set 8 | lamu
# Processing Record 46 of Set 8 | doka
# Processing Record 47 of Set 8 | skjervoy
# Processing Record 48 of Set 8 | fortuna
# Processing Record 49 of Set 8 | waw
# Processing Record 50 of Set 8 | laguna
# Processing Record 1 of Set 9 | sechura
# Processing Record 2 of Set 9 | neryungri
# Processing Record 3 of Set 9 | anadyr
# Processing Record 4 of Set 9 | kolo
# Processing Record 5 of Set 9 | katsuura
# Processing Record 6 of Set 9 | jos
# Processing Record 7 of Set 9 | portland
# Processing Record 8 of Set 9 | candido mendes
# Processing Record 9 of Set 9 | santa clara
# Processing Record 10 of Set 9 | labuhan
# Processing Record 11 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 9 | khash
# Processing Record 13 of Set 9 | riyadh
# Processing Record 14 of Set 9 | dolores
# Processing Record 15 of Set 9 | esmeraldas
# Processing Record 16 of Set 9 | flin flon
# Processing Record 17 of Set 9 | santa cruz
# Processing Record 18 of Set 9 | leninskoye
# Processing Record 19 of Set 9 | hvide sande
# Processing Record 20 of Set 9 | west plains
# Processing Record 21 of Set 9 | worcester
# Processing Record 22 of Set 9 | pizarro
# Processing Record 23 of Set 9 | lata
# Processing Record 24 of Set 9 | cockburn town
# Processing Record 25 of Set 9 | saint-pierre
# Processing Record 26 of Set 9 | xingtai
# Processing Record 27 of Set 9 | okhotsk
# Processing Record 28 of Set 9 | shakiso
# Processing Record 29 of Set 9 | puerto escondido
# Processing Record 30 of Set 9 | aswan
# Processing Record 31 of Set 9 | hebi
# Processing Record 32 of Set 9 | coquimbo
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | kapoeta
# Processing Record 35 of Set 9 | iqaluit
# Processing Record 36 of Set 9 | rochelle
# Processing Record 37 of Set 9 | sur
# Processing Record 38 of Set 9 | svetlyy
# Processing Record 39 of Set 9 | mashhad
# Processing Record 40 of Set 9 | abu kamal
# Processing Record 41 of Set 9 | abong mbang
# Processing Record 42 of Set 9 | ixtapa
# Processing Record 43 of Set 9 | nikolskoye
# Processing Record 44 of Set 9 | wageningen
# Processing Record 45 of Set 9 | ballina
# Processing Record 46 of Set 9 | kristiinankaupunki
# Processing Record 47 of Set 9 | yuci
# Processing Record 48 of Set 9 | handwara
# City not found. Skipping...
# Processing Record 49 of Set 9 | mahabad
# Processing Record 50 of Set 9 | shingu
# Processing Record 1 of Set 10 | harduaganj
# Processing Record 2 of Set 10 | qeshm
# Processing Record 3 of Set 10 | gravdal
# Processing Record 4 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 5 of Set 10 | sol-iletsk
# Processing Record 6 of Set 10 | tamra
# Processing Record 7 of Set 10 | nikolayevka
# Processing Record 8 of Set 10 | kudahuvadhoo
# Processing Record 9 of Set 10 | svetlogorsk
# Processing Record 10 of Set 10 | harper
# Processing Record 11 of Set 10 | narsaq
# Processing Record 12 of Set 10 | songjianghe
# Processing Record 13 of Set 10 | perth
# Processing Record 14 of Set 10 | popondetta
# Processing Record 15 of Set 10 | yei
# Processing Record 16 of Set 10 | santo antonio do sudoeste
# Processing Record 17 of Set 10 | bredy
# Processing Record 18 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 10 | cruden bay
# City not found. Skipping...
# Processing Record 20 of Set 10 | pucallpa
# Processing Record 21 of Set 10 | loreto
# Processing Record 22 of Set 10 | roswell
# Processing Record 23 of Set 10 | kismayo
# Processing Record 24 of Set 10 | abu dhabi
# Processing Record 25 of Set 10 | san juan
# Processing Record 26 of Set 10 | uruzgan
# Processing Record 27 of Set 10 | atocha
# Processing Record 28 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | dovolnoye
# Processing Record 31 of Set 10 | saint anthony
# Processing Record 32 of Set 10 | qui nhon
# Processing Record 33 of Set 10 | bahia de caraquez
# Processing Record 34 of Set 10 | ilebo
# Processing Record 35 of Set 10 | lisala
# Processing Record 36 of Set 10 | buckeye
# Processing Record 37 of Set 10 | guca
# Processing Record 38 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 10 | luba
# Processing Record 40 of Set 10 | sillod
# Processing Record 41 of Set 10 | nioro
# Processing Record 42 of Set 10 | stutterheim
# Processing Record 43 of Set 10 | dongfeng
# Processing Record 44 of Set 10 | vagur
# Processing Record 45 of Set 10 | corinth
# Processing Record 46 of Set 10 | bairiki
# Processing Record 47 of Set 10 | lazaro cardenas
# Processing Record 48 of Set 10 | poum
# Processing Record 49 of Set 10 | nishihara
# Processing Record 50 of Set 10 | kahului
# Processing Record 1 of Set 11 | fare
# Processing Record 2 of Set 11 | saint george
# Processing Record 3 of Set 11 | danielskuil
# Processing Record 4 of Set 11 | sitia
# Processing Record 5 of Set 11 | sinnamary
# Processing Record 6 of Set 11 | paamiut
# Processing Record 7 of Set 11 | rio gallegos
# Processing Record 8 of Set 11 | srednekolymsk
# Processing Record 9 of Set 11 | peace river
# Processing Record 10 of Set 11 | almazar
# Processing Record 11 of Set 11 | orlovskiy
# Processing Record 12 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 11 | berdyuzhye
# City not found. Skipping...
# Processing Record 14 of Set 11 | panji
# Processing Record 15 of Set 11 | svolvaer
# Processing Record 16 of Set 11 | grindavik
# Processing Record 17 of Set 11 | sri aman
# Processing Record 18 of Set 11 | asau
# Processing Record 19 of Set 11 | manta
# Processing Record 20 of Set 11 | la rioja
# Processing Record 21 of Set 11 | boden
# Processing Record 22 of Set 11 | tiszanana
# Processing Record 23 of Set 11 | kikugawa
# Processing Record 24 of Set 11 | angoche
# Processing Record 25 of Set 11 | bathsheba
# Processing Record 26 of Set 11 | panacan
# Processing Record 27 of Set 11 | praya
# Processing Record 28 of Set 11 | nouna
# Processing Record 29 of Set 11 | gornyy
# Processing Record 30 of Set 11 | mogadishu
# Processing Record 31 of Set 11 | am timan
# Processing Record 32 of Set 11 | barabinsk
# Processing Record 33 of Set 11 | rancho palos verdes
# Processing Record 34 of Set 11 | varhaug
# Processing Record 35 of Set 11 | lompoc
# Processing Record 36 of Set 11 | yonibana
# Processing Record 37 of Set 11 | melo
# Processing Record 38 of Set 11 | sakaiminato
# Processing Record 39 of Set 11 | tura
# Processing Record 40 of Set 11 | kirakira
# Processing Record 41 of Set 11 | vanimo
# Processing Record 42 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 43 of Set 11 | ugoofaaru
# Processing Record 44 of Set 11 | tigre
# Processing Record 45 of Set 11 | mangrol
# Processing Record 46 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 47 of Set 11 | hovd
# Processing Record 48 of Set 11 | uray
# Processing Record 49 of Set 11 | soltau
# Processing Record 50 of Set 11 | amapa
# Processing Record 1 of Set 12 | moron
# Processing Record 2 of Set 12 | bima
# Processing Record 3 of Set 12 | pangnirtung
# Processing Record 4 of Set 12 | galeana
# Processing Record 5 of Set 12 | ayan
# Processing Record 6 of Set 12 | hofn
# Processing Record 7 of Set 12 | lincoln
# Processing Record 8 of Set 12 | nalut
# Processing Record 9 of Set 12 | eureka
# Processing Record 10 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 12 | usta muhammad
# Processing Record 12 of Set 12 | honningsvag
# Processing Record 13 of Set 12 | usogorsk
# Processing Record 14 of Set 12 | ostashkov
# Processing Record 15 of Set 12 | ambilobe
# Processing Record 16 of Set 12 | jijiga
# Processing Record 17 of Set 12 | bay roberts
# Processing Record 18 of Set 12 | duartina
# Processing Record 19 of Set 12 | seddon
# Processing Record 20 of Set 12 | port augusta
# Processing Record 21 of Set 12 | conde
# Processing Record 22 of Set 12 | hambantota
# Processing Record 23 of Set 12 | pemangkat
# Processing Record 24 of Set 12 | abu zabad
# Processing Record 25 of Set 12 | shimanovsk
# Processing Record 26 of Set 12 | taoudenni
# Processing Record 27 of Set 12 | banes
# Processing Record 28 of Set 12 | lambarene
# Processing Record 29 of Set 12 | atar
# Processing Record 30 of Set 12 | lasa
# Processing Record 31 of Set 12 | kalmar
# Processing Record 32 of Set 12 | chapais
# Processing Record 33 of Set 12 | bardiyah
# Processing Record 34 of Set 12 | isetskoye
# Processing Record 35 of Set 12 | thunder bay
# Processing Record 36 of Set 12 | benguela
# Processing Record 37 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 12 | chifeng
# Processing Record 39 of Set 12 | montelimar
# Processing Record 40 of Set 12 | narrabri
# Processing Record 41 of Set 12 | kyzyl-suu
# Processing Record 42 of Set 12 | domat
# Processing Record 43 of Set 12 | spring valley
# Processing Record 44 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 45 of Set 12 | caravelas
# Processing Record 46 of Set 12 | maine-soroa
# Processing Record 47 of Set 12 | bela vista
# Processing Record 48 of Set 12 | nautla
# Processing Record 49 of Set 12 | damghan
# Processing Record 50 of Set 12 | sangueya
# Processing Record 1 of Set 13 | dubbo
# Processing Record 2 of Set 13 | usinsk
# Processing Record 3 of Set 13 | luau
# Processing Record 4 of Set 13 | kaeo
# Processing Record 5 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 13 | trat
# Processing Record 7 of Set 13 | jawhar
# Processing Record 8 of Set 13 | tsiroanomandidy
# Processing Record 9 of Set 13 | la ronge
# Processing Record 10 of Set 13 | caluquembe
# Processing Record 11 of Set 13 | kuytun
# Processing Record 12 of Set 13 | banda aceh
# Processing Record 13 of Set 13 | tralee
# Processing Record 14 of Set 13 | iranshahr
# Processing Record 15 of Set 13 | ormara
# Processing Record 16 of Set 13 | biak
# Processing Record 17 of Set 13 | hurghada
# Processing Record 18 of Set 13 | kupang
# Processing Record 19 of Set 13 | vaitape
# Processing Record 20 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 21 of Set 13 | vestmannaeyjar
# Processing Record 22 of Set 13 | turukhansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Roros  62.5747   11.3842     12.20        73          90
# 1     Hithadhoo  -0.6000   73.0833     81.90        78          83
# 2  Punta Arenas -53.1500  -70.9167     48.20        57          40
# 3  Puerto Ayora  -0.7393  -90.3518     75.00        91          96
# 4         Bilma  18.6853   12.9164     61.52        28           0
# 5    Butaritari   3.0707  172.7902     81.37        80          99
# 6   Tuktoyaktuk  69.4541 -133.0374     -0.40        78          90
# 7      Hamilton  39.1834  -84.5333     33.01        69           1
# 8   Zelenoborsk  61.4669   64.0333    -16.06        86          37
# 9       Honiara  -9.4333  159.9500     79.18        76         100
#
#    Wind Speed Country                 Date
# 0        4.61      NO  2021-01-13 00:00:02
# 1       19.44      MV  2021-01-13 00:00:03
# 2       17.27      CL  2021-01-12 23:59:14
# 3        4.00      EC  2021-01-13 00:00:05
# 4        1.39      NE  2021-01-13 00:00:08
# 5       20.04      KI  2021-01-13 00:00:10
# 6       19.57      CA  2021-01-13 00:00:10
# 7        5.75      US  2021-01-12 23:56:46
# 8        3.09      RU  2021-01-13 00:00:11
# 9        1.12      SB  2021-01-12 23:55:12

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_new_df = city_data_df[new_column_order]
city_data_new_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0         Roros      NO  2021-01-13 00:00:02  62.5747   11.3842     12.20
# 1     Hithadhoo      MV  2021-01-13 00:00:03  -0.6000   73.0833     81.90
# 2  Punta Arenas      CL  2021-01-12 23:59:14 -53.1500  -70.9167     48.20
# 3  Puerto Ayora      EC  2021-01-13 00:00:05  -0.7393  -90.3518     75.00
# 4         Bilma      NE  2021-01-13 00:00:08  18.6853   12.9164     61.52
# 5    Butaritari      KI  2021-01-13 00:00:10   3.0707  172.7902     81.37
# 6   Tuktoyaktuk      CA  2021-01-13 00:00:10  69.4541 -133.0374     -0.40
# 7      Hamilton      US  2021-01-12 23:56:46  39.1834  -84.5333     33.01
# 8   Zelenoborsk      RU  2021-01-13 00:00:11  61.4669   64.0333    -16.06
# 9       Honiara      SB  2021-01-12 23:55:12  -9.4333  159.9500     79.18
#
#    Humidity  Cloudiness  Wind Speed
# 0        73          90        4.61
# 1        78          83       19.44
# 2        57          40       17.27
# 3        91          96        4.00
# 4        28           0        1.39
# 5        80          99       20.04
# 6        78          90       19.57
# 7        69           1        5.75
# 8        86          37        3.09
# 9        76         100        1.12

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
